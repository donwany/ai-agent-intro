# %%
import os
import asyncio
from dotenv import load_dotenv
from semantic_kernel.agents import ChatCompletionAgent
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       1 import os
#       2 import asyncio
#       3 from dotenv import load_dotenv
# ----> 4 from semantic_kernel.agents import ChatCompletionAgent
#       5 from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion
#
# File ~/Desktop/PythonCourse/ai-ml-course/lesson19/.venv/lib/python3.12/site-packages/semantic_kernel/__init__.py:3
#       1 # Copyright (c) Microsoft. All rights reserved.
# ----> 3 from semantic_kernel.kernel import Kernel
#       5 __all__ = ["Kernel"]
#
# File ~/Desktop/PythonCourse/ai-ml-course/lesson19/.venv/lib/python3.12/site-packages/semantic_kernel/kernel.py:8
#       5 from copy import copy
#       6 from typing import TYPE_CHECKING, Any, Literal, TypeVar
# ----> 8 from semantic_kernel.connectors.ai.embeddings.embedding_generator_base import EmbeddingGeneratorBase
#       9 from semantic_kernel.const import METADATA_EXCEPTION_KEY
#      10 from semantic_kernel.contents.chat_history import ChatHistory
#
# File ~/Desktop/PythonCourse/ai-ml-course/lesson19/.venv/lib/python3.12/site-packages/semantic_kernel/connectors/ai/__init__.py:3
#       1 # Copyright (c) Microsoft. All rights reserved.
# ----> 3 from semantic_kernel.connectors.ai.prompt_execution_settings import PromptExecutionSettings
#       5 __all__ = ["PromptExecutionSettings"]
#
# File ~/Desktop/PythonCourse/ai-ml-course/lesson19/.venv/lib/python3.12/site-packages/semantic_kernel/connectors/ai/prompt_execution_settings.py:8
#       4 from typing import Any, TypeVar
#       6 from pydantic import Field, model_validator
# ----> 8 from semantic_kernel.connectors.ai.function_choice_behavior import FunctionChoiceBehavior
#       9 from semantic_kernel.kernel_pydantic import KernelBaseModel
#      11 logger = logging.getLogger(__name__)
#
# File ~/Desktop/PythonCourse/ai-ml-course/lesson19/.venv/lib/python3.12/site-packages/semantic_kernel/connectors/ai/function_choice_behavior.py:10
#       6 from typing import TYPE_CHECKING, Literal, TypeVar
#       8 from typing_extensions import deprecated
# ---> 10 from semantic_kernel.connectors.ai.function_calling_utils import _combine_filter_dicts
#      11 from semantic_kernel.exceptions.service_exceptions import ServiceInitializationError
#      12 from semantic_kernel.kernel_pydantic import KernelBaseModel
#
# File ~/Desktop/PythonCourse/ai-ml-course/lesson19/.venv/lib/python3.12/site-packages/semantic_kernel/connectors/ai/function_calling_utils.py:6
#       3 from collections import OrderedDict
#       4 from typing import TYPE_CHECKING, Any
# ----> 6 from semantic_kernel.contents.chat_message_content import ChatMessageContent
#       7 from semantic_kernel.contents.function_result_content import FunctionResultContent
#       8 from semantic_kernel.contents.utils.author_role import AuthorRole
#
# File ~/Desktop/PythonCourse/ai-ml-course/lesson19/.venv/lib/python3.12/site-packages/semantic_kernel/contents/__init__.py:3
#       1 # Copyright (c) Microsoft. All rights reserved.
# ----> 3 from semantic_kernel.contents.annotation_content import AnnotationContent
#       4 from semantic_kernel.contents.chat_history import ChatHistory
#       5 from semantic_kernel.contents.chat_message_content import ChatMessageContent
#
# File ~/Desktop/PythonCourse/ai-ml-course/lesson19/.venv/lib/python3.12/site-packages/semantic_kernel/contents/annotation_content.py:10
#       7 from pydantic import Field
#       9 from semantic_kernel.contents.const import ANNOTATION_CONTENT_TAG, ContentTypes
# ---> 10 from semantic_kernel.contents.kernel_content import KernelContent
#      11 from semantic_kernel.utils.experimental_decorator import experimental_class
#      13 logger = logging.getLogger(__name__)
#
# File ~/Desktop/PythonCourse/ai-ml-course/lesson19/.venv/lib/python3.12/site-packages/semantic_kernel/contents/kernel_content.py:8
#       4 from typing import Any, TypeVar
#       6 from pydantic import Field
# ----> 8 from semantic_kernel.kernel_pydantic import KernelBaseModel
#      10 _T = TypeVar("_T", bound="KernelContent")
#      13 class KernelContent(KernelBaseModel, ABC):
#
# File ~/Desktop/PythonCourse/ai-ml-course/lesson19/.venv/lib/python3.12/site-packages/semantic_kernel/kernel_pydantic.py:7
#       4 from typing import Annotated, Any, ClassVar, TypeVar
#       6 from pydantic import BaseModel, ConfigDict, Field, UrlConstraints
# ----> 7 from pydantic.networks import Url
#       8 from pydantic_settings import BaseSettings, SettingsConfigDict
#      10 HttpsUrl = Annotated[Url, UrlConstraints(max_length=2083, allowed_schemes=["https"])]
#
# ImportError: cannot import name 'Url' from 'pydantic.networks' (/Users/tsiameh/Desktop/PythonCourse/ai-ml-course/lesson19/.venv/lib/python3.12/site-packages/pydantic/networks.py)

# %%
import semantic_kernel as sk

print(sk.__version__)

# %%
load_dotenv()

# %%
async def main():
    # Initialize a chat agent with basic instructions
    agent = ChatCompletionAgent(
        service=AzureChatCompletion(),
        name="SK-Assistant",
        instructions="You are a helpful assistant.",
    )

    # Get a response to a user message
    response = await agent.get_response(messages="Write a haiku about Semantic Kernel.")
    print(response.content)

# asyncio.run(main())
await main()

# Output:
# Language's essence,
# Semantic threads intertwine,
# Meaning's core revealed.
