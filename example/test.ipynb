# %%
import asyncio

from agents import Agent, Runner
# Out:
# Running cells with 'lesson19 (3.14.3) (Python 3.14.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/tsiameh/Desktop/PythonCourse/ai-ml-course/lesson19/.venv/bin/python -m pip install ipykernel -U --force-reinstall'
