# %% [markdown]
# ## Cosine Similarity

# %%
import numpy as np

A = np.array([1, 2, 3])
B = np.array([4, 5, 6])

norm_A = np.linalg.norm(A)
norm_B = np.linalg.norm(B)
print(f"Norm of A: {norm_A:.4f}")
print(f"Norm of B: {norm_B:.4f}")

dot_product = np.dot(A, B)
print(f"Dot product of A and B: {dot_product:.4f}")

cosine_similarity = dot_product / (norm_A * norm_B)

print(f"Cosine similarity of A and B: {cosine_similarity:.4f}")
# Out:
# Norm of A: 3.7417
# Norm of B: 8.7750
# Dot product of A and B: 32.0000
# Cosine similarity of A and B: 0.9746

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content="this is the main text content I am using to create RAG",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Donald Trump",
        "date_created":"2026-07-01"
    }
)

doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Donald Trump', 'date_created': '2026-07-01'}, page_content='this is the main text content I am using to create RAG')

# %%
doc.page_content
# Out:
# 'this is the main text content I am using to create RAG'

# %%
doc.metadata
# Out:
# {'source': 'example.txt',
#  'pages': 1,
#  'author': 'Donald Trump',
#  'date_created': '2026-07-01'}

# %%
doc.metadata['author']
# Out:
# 'Donald Trump'

# %%
doc.metadata['date_created']
# Out:
# '2026-07-01'

# %%
data = [
    Document(
        metadata={'source': 'machine_learning.txt'}, 
        page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n'
        ),
    Document(
        metadata={'source': 'python_intro.txt'}, 
        page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.'
        )
]

data
# Out:
# [Document(metadata={'source': 'machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n'),
#  Document(metadata={'source': 'python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from IPython.display import Markdown, display

display(Markdown(data[0].page_content))
# Out:
# Machine Learning Basics
#
# Machine learning is a subset of artificial intelligence that enables systems to learn and improve
# from experience without being explicitly programmed. It focuses on developing computer programs
# that can access data and use it to learn for themselves.
#
# Types of Machine Learning:
# 1. Supervised Learning: Learning with labeled data
# 2. Unsupervised Learning: Finding patterns in unlabeled data
# 3. Reinforcement Learning: Learning through rewards and penalties
#
# Applications include image recognition, speech processing, and recommendation systems

# %%
display(Markdown(data[1].page_content))
